# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanshreeRaut/Pattern-Recognition/blob/main/CM23059.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

print("Array:", arr)
print("Mean:", np.mean(arr))
print("Sum:", np.sum(arr))
# Out:
# Array: [10 20 30 40 50]
# Mean: 30.0
# Sum: 150

# %%
import pandas as pd

data = {
    'Name': ['Amit', 'Rahul', 'Priya'],
    'Marks': [85, 90, 88]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Marks
# 0   Amit     85
# 1  Rahul     90
# 2  Priya     88

# %%
import pandas as pd

data = {
    'Name': ['Amit', 'Rahul', 'Priya'],
    'Marks': [85, 90, 88]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Marks
# 0   Amit     85
# 1  Rahul     90
# 2  Priya     88

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]

plt.plot(x, y)
plt.title("Simple Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = np.zeros((200, 200, 3), dtype=np.uint8)

cv2.circle(img, (100, 100), 50, (255, 0, 0), -1)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.show()

# %%
import tensorflow as tf

a = tf.constant(10)
b = tf.constant(20)

c = a + b

print("Result:", c.numpy())
# Out:
# Result: 30

# %%
from sklearn.datasets import load_iris
import pandas as pd
import matplotlib.pyplot as plt

iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df['sepal length (cm)'].hist(bins=10)

plt.title("Histogram of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")
plt.show()
